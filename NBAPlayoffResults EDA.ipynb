# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NBADataPlayoffResults.csv')

# %%
df.head()
# Out:
#           TEAM   PACE  PACEvsLA   AST    TO   ORR   DRR  REBR  EFF FG%  \
# 0     Brooklyn  101.8      0.38  19.5  12.2  21.4  77.6  50.8     57.5
# 1  LA Clippers   99.1     -2.32  18.4  12.2  22.7  79.5  51.7     56.4
# 2         Utah  100.8     -0.62  17.5  12.7  24.5  78.7  53.1     56.3
# 3      Phoenix   99.3     -2.12  19.8  11.5  20.8  78.7  50.1     56.4
# 4     Portland  100.8     -0.62  16.0   9.9  23.0  76.3  49.5     54.0
#
#    EFFFGvsLA   TS%  TSvsLA  OFF EFF  OFFEFFvsLA  DEF EFF  DEFEFFvsLA  NET EFF  \
# 0        3.7  61.0    3.82    116.3         6.4    110.6         0.7      5.7
# 1        2.6  59.9    2.72    115.2         5.3    108.7        -1.2      6.5
# 2        2.5  59.7    2.52    115.1         5.2    105.7        -4.2      9.4
# 3        2.6  59.7    2.52    114.9         5.0    108.8        -1.1      6.1
# 4        0.2  57.7    0.52    114.9         5.0    113.4         3.5      1.5
#
#    Result  Season
# 0       2    2021
# 1       3    2021
# ...

# %%
X = df.drop(columns = ['PACE', 'EFF FG%', 'TS%','OFF EFF','DEF EFF','TEAM', 'Season'])

# %%
X.head()
# Out:
#    PACEvsLA   AST    TO   ORR   DRR  REBR  EFFFGvsLA  TSvsLA  OFFEFFvsLA  \
# 0      0.38  19.5  12.2  21.4  77.6  50.8        3.7    3.82         6.4
# 1     -2.32  18.4  12.2  22.7  79.5  51.7        2.6    2.72         5.3
# 2     -0.62  17.5  12.7  24.5  78.7  53.1        2.5    2.52         5.2
# 3     -2.12  19.8  11.5  20.8  78.7  50.1        2.6    2.52         5.0
# 4     -0.62  16.0   9.9  23.0  76.3  49.5        0.2    0.52         5.0
#
#    DEFEFFvsLA  NET EFF  Result
# 0         0.7      5.7       2
# 1        -1.2      6.5       3
# 2        -4.2      9.4       2
# 3        -1.1      6.1       4
# 4         3.5      1.5       1

# %%
sns.barplot(x = 'Result', y = 'PACEvsLA', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='PACEvsLA'>

# %%
sns.barplot(x = 'Result', y = 'AST', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='AST'>

# %%
sns.barplot(x = 'Result', y = 'TO', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='TO'>

# %%
sns.barplot(x = 'Result', y = 'ORR', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='ORR'>

# %%
sns.barplot(x = 'Result', y = 'DRR', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='DRR'>

# %%
sns.barplot(x = 'Result', y = 'REBR', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='REBR'>

# %%
sns.barplot(x = 'Result', y = 'EFFFGvsLA', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='EFFFGvsLA'>

# %%
sns.barplot(x = 'Result', y = 'TSvsLA', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='TSvsLA'>

# %%
sns.barplot(x = 'Result', y = 'OFFEFFvsLA', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='OFFEFFvsLA'>

# %%
sns.barplot(x = 'Result', y = 'DEFEFFvsLA', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='DEFEFFvsLA'>

# %%
sns.barplot(x = 'Result', y = 'NET EFF', data = X, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='NET EFF'>

# %%
sns.boxplot(x = 'Result', y = 'EFFFGvsLA', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='EFFFGvsLA'>

# %%
sns.boxplot(x = 'Result', y = 'TSvsLA', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='TSvsLA'>

# %%
sns.boxplot(x = 'Result', y = 'OFFEFFvsLA', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='OFFEFFvsLA'>

# %%
sns.boxplot(x = 'Result', y = 'NET EFF', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='NET EFF'>

# %%
sns.boxplot(x = 'Result', y = 'DEFEFFvsLA', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='DEFEFFvsLA'>

# %%
sns.swarmplot(x = 'Result', y = 'EFFFGvsLA', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='EFFFGvsLA'>

# %%
sns.swarmplot(x = 'Result', y = 'TSvsLA', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='TSvsLA'>

# %%
sns.swarmplot(x = 'Result', y = 'OFFEFFvsLA', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='OFFEFFvsLA'>

# %%
sns.swarmplot(x = 'Result', y = 'DEFEFFvsLA', data = X)
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Result', ylabel='DEFEFFvsLA'>

# %%
sns.swarmplot(x = 'Result', y = 'NET EFF', data = X)
# Out:
# <AxesSubplot:xlabel='Result', ylabel='NET EFF'>

# %%
predictive = X.drop(columns = ['PACEvsLA', 'ORR', 'DRR', 'REBR', 'AST', 'TO', 'Result'])

# %%
sns.pairplot(predictive)

# %%
df.groupby('Season').mean()['AST']
# Out:
# Season
# 2016    16.923333
# 2017    17.100000
# 2018    17.443333
# 2019    17.786667
# 2020    17.656667
# 2021    18.143333
# Name: AST, dtype: float64

# %%
df.groupby('Season').mean()['TO']
# Out:
# Season
# 2016    13.153333
# 2017    12.740000
# 2018    12.980000
# 2019    12.400000
# 2020    12.826667
# 2021    12.360000
# Name: TO, dtype: float64

# %%
df.groupby('Season').mean()['ORR']
# Out:
# Season
# 2016    23.813333
# 2017    23.296667
# 2018    22.323333
# 2019    22.893333
# 2020    22.486667
# 2021    22.193333
# Name: ORR, dtype: float64

# %%
df.groupby('Season').mean()['DRR']
# Out:
# Season
# 2016    76.213333
# 2017    76.723333
# 2018    77.686667
# 2019    77.070000
# 2020    77.463333
# 2021    77.830000
# Name: DRR, dtype: float64

# %%
df.groupby('Season').mean()['REBR']
# Out:
# Season
# 2016    50.003333
# 2017    49.996667
# 2018    49.990000
# 2019    49.983333
# 2020    49.966667
# 2021    50.006667
# Name: REBR, dtype: float64

# %%
df.groupby('Season').mean()['PACE']
# Out:
# Season
# 2016     98.083333
# 2017     98.720000
# 2018     99.563333
# 2019    102.390000
# 2020    102.683333
# 2021    101.420000
# Name: PACE, dtype: float64

# %%
df.groupby('Season').mean()['EFF FG%']
# Out:
# Season
# 2016    50.250000
# 2017    51.386667
# 2018    52.126667
# 2019    52.416667
# 2020    52.836667
# 2021    53.796667
# Name: EFF FG%, dtype: float64

# %%
df.groupby('Season').mean()['TS%']
# Out:
# Season
# 2016    54.130000
# 2017    55.243333
# 2018    55.620000
# 2019    55.960000
# 2020    56.426667
# 2021    57.180000
# Name: TS%, dtype: float64

# %%
df.groupby('Season').mean()['OFF EFF']
# Out:
# Season
# 2016    103.906667
# 2017    106.240000
# 2018    106.176667
# 2019    107.853333
# 2020    107.970000
# 2021    109.876667
# Name: OFF EFF, dtype: float64

# %%
df.groupby('Season').mean()['DEF EFF']
# Out:
# Season
# 2016    103.893333
# 2017    106.216667
# 2018    106.180000
# 2019    107.856667
# 2020    108.153333
# 2021    109.860000
# Name: DEF EFF, dtype: float64
